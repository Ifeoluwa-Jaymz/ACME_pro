# %% [markdown]
# <a href="https://colab.research.google.com/github/Ifeoluwa-Jaymz/ACME_pro/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U pip
# !pip install -U setuptools wheel
# !pip install -U "mxnet<2.0.0" bokeh==2.0.1
# !pip install autogluon --no-cache-dir
# # Without --no-cache-dir, smaller aws instances may have trouble installing

# %%
# !mkdir -p /root/.kaggle
# !touch /root/.kaggle/kaggle.json
# !chmod 600 /root/.kaggle/kaggle.json

# %%
# import json
# kaggle_username = "afolabiifeoluwajames"
# kaggle_key = "f443f2eb97a17ccb8cb9f96b26d78aad"

# # Save API token the kaggle.json file
# with open("/root/.kaggle/kaggle.json", "w") as f:
#     f.write(json.dumps({"username": kaggle_username, "key": kaggle_key}))

# %%
# !kaggle competitions download -c bike-sharing-demand
# # If you already downloaded it you can use the -o command to overwrite the file
# !unzip -o bike-sharing-demand.zip

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib as plt
# %matplotlib inline
import seaborn as sns
from sklearn.model_selection import train_test_split,cross_validate
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error

# %%
train = pd.read_csv('/content/train.csv')
test = pd.read_csv('/content/test.csv')
train.head()
# Out:
#               datetime  season  holiday  workingday  weather  temp   atemp  \
# 0  2011-01-01 00:00:00       1        0           0        1  9.84  14.395
# 1  2011-01-01 01:00:00       1        0           0        1  9.02  13.635
# 2  2011-01-01 02:00:00       1        0           0        1  9.02  13.635
# 3  2011-01-01 03:00:00       1        0           0        1  9.84  14.395
# 4  2011-01-01 04:00:00       1        0           0        1  9.84  14.395
#
#    humidity  windspeed  casual  registered  count
# 0        81        0.0       3          13     16
# 1        80        0.0       8          32     40
# 2        80        0.0       5          27     32
# 3        75        0.0       3          10     13
# 4        75        0.0       0           1      1

# %%
print("train shape:",train.shape)
print("test shape :",test.shape)
# Out:
# train shape: (10886, 12)
# test shape : (6493, 9)

# %%
train.info()
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10886 entries, 0 to 10885
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    10886 non-null  object
#  1   season      10886 non-null  int64
#  2   holiday     10886 non-null  int64
#  3   workingday  10886 non-null  int64
#  4   weather     10886 non-null  int64
#  5   temp        10886 non-null  float64
#  6   atemp       10886 non-null  float64
#  7   humidity    10886 non-null  int64
#  8   windspeed   10886 non-null  float64
#  9   casual      10886 non-null  int64
#  10  registered  10886 non-null  int64
#  11  count       10886 non-null  int64
# dtypes: float64(3), int64(8), object(1)
# memory usage: 1020.7+ KB
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6493 entries, 0 to 6492
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   datetime    6493 non-null   object
#  1   season      6493 non-null   int64
#  2   holiday     6493 non-null   int64
#  3   workingday  6493 non-null   int64
#  4   weather     6493 non-null   int64
#  5   temp        6493 non-null   float64
#  6   atemp       6493 non-null   float64
#  7   humidity    6493 non-null   int64
#  8   windspeed   6493 non-null   float64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 456.7+ KB

# %%
train.describe()
# Out:
#              season       holiday    workingday       weather         temp  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.00000
# mean       2.506614      0.028569      0.680875      1.418427     20.23086
# std        1.116174      0.166599      0.466159      0.633839      7.79159
# min        1.000000      0.000000      0.000000      1.000000      0.82000
# 25%        2.000000      0.000000      0.000000      1.000000     13.94000
# 50%        3.000000      0.000000      1.000000      1.000000     20.50000
# 75%        4.000000      0.000000      1.000000      2.000000     26.24000
# max        4.000000      1.000000      1.000000      4.000000     41.00000
#
#               atemp      humidity     windspeed        casual    registered  \
# count  10886.000000  10886.000000  10886.000000  10886.000000  10886.000000
# mean      23.655084     61.886460     12.799395     36.021955    155.552177
# std        8.474601     19.245033      8.164537     49.960477    151.039033
# min        0.760000      0.000000      0.000000      0.000000      0.000000
# 25%       16.665000     47.000000      7.001500      4.000000     36.000000
# 50%       24.240000     62.000000     12.998000     17.000000    118.000000
# 75%       31.060000     77.000000     16.997900     49.000000    222.000000
# max       45.455000    100.000000     56.996900    367.000000    886.000000
#
#               count
# count  10886.000000
# mean     191.574132
# std      181.144454
# min        1.000000
# 25%       42.000000
# 50%      145.000000
# 75%      284.000000
# max      977.000000

# %%
# pip install pandas-profiling

# %%
# from pandas_profiling import ProfileReport

# profile = ProfileReport( train, title='Pandas profiling report ' , html={'style':{'full_width':True}})

# profile.to_notebook_iframe()

# %%
sns.pairplot(train ,kind="reg")

# %%
season=pd.get_dummies(train['season'],prefix='season')
dtrain_stf=pd.concat([train,season],axis=1)
train.head()
season=pd.get_dummies(test['season'],prefix='season')
test_st=pd.concat([test,season],axis=1)
test_st.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  season_1  season_2  season_3  season_4
# 0        56    26.0027      True     False     False     False
# 1        56     0.0000      True     False     False     False
# 2        56     0.0000      True     False     False     False
# 3        56    11.0014      True     False     False     False
# 4        56    11.0014      True     False     False     False

# %%
weather=pd.get_dummies(train['weather'],prefix='weather')
train=pd.concat([train,weather],axis=1)
train.head()
weather=pd.get_dummies(test['weather'],prefix='weather')
test=pd.concat([test,weather],axis=1)
test.head()
# Out:
#               datetime  season  holiday  workingday  weather   temp   atemp  \
# 0  2011-01-20 00:00:00       1        0           1        1  10.66  11.365
# 1  2011-01-20 01:00:00       1        0           1        1  10.66  13.635
# 2  2011-01-20 02:00:00       1        0           1        1  10.66  13.635
# 3  2011-01-20 03:00:00       1        0           1        1  10.66  12.880
# 4  2011-01-20 04:00:00       1        0           1        1  10.66  12.880
#
#    humidity  windspeed  weather_1  weather_2  weather_3  weather_4
# 0        56    26.0027       True      False      False      False
# 1        56     0.0000       True      False      False      False
# 2        56     0.0000       True      False      False      False
# 3        56    11.0014       True      False      False      False
# 4        56    11.0014       True      False      False      False

# %%
train.drop(['season','weather'],inplace=True,axis=1)
train.head()
test.drop(['season','weather'],inplace=True,axis=1)
test.head()
# Out:
#               datetime  holiday  workingday   temp   atemp  humidity  \
# 0  2011-01-20 00:00:00        0           1  10.66  11.365        56
# 1  2011-01-20 01:00:00        0           1  10.66  13.635        56
# 2  2011-01-20 02:00:00        0           1  10.66  13.635        56
# 3  2011-01-20 03:00:00        0           1  10.66  12.880        56
# 4  2011-01-20 04:00:00        0           1  10.66  12.880        56
#
#    windspeed  weather_1  weather_2  weather_3  weather_4
# 0    26.0027       True      False      False      False
# 1     0.0000       True      False      False      False
# 2     0.0000       True      False      False      False
# 3    11.0014       True      False      False      False
# 4    11.0014       True      False      False      False

# %%
train["hour"] = [t.hour for t in pd.DatetimeIndex(train.datetime)]
train["day"] = [t.dayofweek for t in pd.DatetimeIndex(train.datetime)]
train["month"] = [t.month for t in pd.DatetimeIndex(train.datetime)]
train['year'] = [t.year for t in pd.DatetimeIndex(train.datetime)]
train['year'] = train['year'].map({2011:0, 2012:1})
train.head()
# Out:
#               datetime  holiday  workingday  temp   atemp  humidity  \
# 0  2011-01-01 00:00:00        0           0  9.84  14.395        81
# 1  2011-01-01 01:00:00        0           0  9.02  13.635        80
# 2  2011-01-01 02:00:00        0           0  9.02  13.635        80
# 3  2011-01-01 03:00:00        0           0  9.84  14.395        75
# 4  2011-01-01 04:00:00        0           0  9.84  14.395        75
#
#    windspeed  casual  registered  count  weather_1  weather_2  weather_3  \
# 0        0.0       3          13     16       True      False      False
# 1        0.0       8          32     40       True      False      False
# 2        0.0       5          27     32       True      False      False
# 3        0.0       3          10     13       True      False      False
# 4        0.0       0           1      1       True      False      False
#
#    weather_4  hour  day  month  year
# 0      False     0    5      1     0
# 1      False     1    5      1     0
# 2      False     2    5      1     0
# 3      False     3    5      1     0
# 4      False     4    5      1     0

# %%
test["hour"] = [t.hour for t in pd.DatetimeIndex(test.datetime)]
test["day"] = [t.dayofweek for t in pd.DatetimeIndex(test.datetime)]
test["month"] = [t.month for t in pd.DatetimeIndex(test.datetime)]
test['year'] = [t.year for t in pd.DatetimeIndex(test.datetime)]
test['year'] = test['year'].map({2011:0, 2012:1})
test.head()
# Out:
#               datetime  holiday  workingday   temp   atemp  humidity  \
# 0  2011-01-20 00:00:00        0           1  10.66  11.365        56
# 1  2011-01-20 01:00:00        0           1  10.66  13.635        56
# 2  2011-01-20 02:00:00        0           1  10.66  13.635        56
# 3  2011-01-20 03:00:00        0           1  10.66  12.880        56
# 4  2011-01-20 04:00:00        0           1  10.66  12.880        56
#
#    windspeed  weather_1  weather_2  weather_3  weather_4  hour  day  month  \
# 0    26.0027       True      False      False      False     0    3      1
# 1     0.0000       True      False      False      False     1    3      1
# 2     0.0000       True      False      False      False     2    3      1
# 3    11.0014       True      False      False      False     3    3      1
# 4    11.0014       True      False      False      False     4    3      1
#
#    year
# 0     0
# 1     0
# 2     0
# 3     0
# 4     0

# %%
train.drop('datetime',axis=1,inplace=True)
train.head()
# Out:
#    holiday  workingday  temp   atemp  humidity  windspeed  casual  registered  \
# 0        0           0  9.84  14.395        81        0.0       3          13
# 1        0           0  9.02  13.635        80        0.0       8          32
# 2        0           0  9.02  13.635        80        0.0       5          27
# 3        0           0  9.84  14.395        75        0.0       3          10
# 4        0           0  9.84  14.395        75        0.0       0           1
#
#    count  weather_1  weather_2  weather_3  weather_4  hour  day  month  year
# 0     16       True      False      False      False     0    5      1     0
# 1     40       True      False      False      False     1    5      1     0
# 2     32       True      False      False      False     2    5      1     0
# 3     13       True      False      False      False     3    5      1     0
# 4      1       True      False      False      False     4    5      1     0

# %%
print(train.columns.values)
# Out:
# ['holiday' 'workingday' 'temp' 'atemp' 'humidity' 'windspeed' 'casual'
#  'registered' 'count' 'weather_1' 'weather_2' 'weather_3' 'weather_4'
#  'hour' 'day' 'month' 'year']

# %%
train.shape
# Out:
# (10886, 17)

# %%
x_train,x_test,y_train,y_test=train_test_split(train.drop('count',axis=1),train['count'],test_size=0.25,random_state=42)

# %%
# !pip install autogluon --no-cache-dir

# %%
from autogluon.tabular import TabularPredictor

# %%
submission = pd.read_csv('sampleSubmission.csv',parse_dates = ['datetime'])
submission.head()
# Out:
#              datetime  count
# 0 2011-01-20 00:00:00      0
# 1 2011-01-20 01:00:00      0
# 2 2011-01-20 02:00:00      0
# 3 2011-01-20 03:00:00      0
# 4 2011-01-20 04:00:00      0

# %%
sns.heatmap(train.corr());

# %%
import warnings
warnings.filterwarnings('ignore')
predictor = TabularPredictor(label='count',eval_metric = 'root_mean_squared_error',
                            learner_kwargs = {"ignored_columns": ["casual", "registered"]}).fit(train_data = train,
                                                                          time_limit =300,
                                                                          presets = 'best_quality')
# Out:
# No path specified. Models will be saved in: "AutogluonModels/ag-20250919_223521"
# Verbosity: 2 (Standard Logging)
# =================== System Info ===================
# AutoGluon Version:  1.4.0
# Python Version:     3.12.11
# Operating System:   Linux
# Platform Machine:   x86_64
# Platform Version:   #1 SMP PREEMPT_DYNAMIC Sun Mar 30 16:01:29 UTC 2025
# CPU Count:          2
# Memory Avail:       10.89 GB / 12.67 GB (85.9%)
# Disk Space Avail:   64.36 GB / 107.72 GB (59.8%)
# ===================================================
# Presets specified: ['best_quality']
# Using hyperparameters preset: hyperparameters='zeroshot'
# Setting dynamic_stacking from 'auto' to True. Reason: Enable dynamic_stacking when use_bag_holdout is disabled. (use_bag_holdout=False)
# Stack configuration (auto_stack=True): num_stack_levels=1, num_bag_folds=8, num_bag_sets=1
# DyStack is enabled (dynamic_stacking=True). AutoGluon will try to determine whether the input data is affected by stacked overfitting and enable or disable stacking as a consequence.
# 	This is used to identify the optimal `num_stack_levels` value. Copies of AutoGluon will be fit on subsets of the data. Then holdout validation data is used to detect stacked overfitting.
# 	Running DyStack for up to 75s of the 300s of remaining time (25%).
# 	Running DyStack sub-fit in a ray process to avoid memory leakage. Enabling ray logging (enable_ray_logging=True). Specify `ds_args={'enable_ray_logging': False}` if you experience logging issues.
# 2025-09-19 22:35:27,188	INFO worker.py:1843 -- Started a local Ray instance. View the dashboard at http://127.0.0.1:8265
# 		Context path: "/content/AutogluonModels/ag-20250919_223521/ds_sub_fit/sub_fit_ho"
# (_dystack pid=9991) Running DyStack sub-fit ...
# (_dystack pid=9991) Beginning AutoGluon training ... Time limit = 67s
# (_dystack pid=9991) AutoGluon will save models to "/content/AutogluonModels/ag-20250919_223521/ds_sub_fit/sub_fit_ho"
# (_dystack pid=9991) Train Data Rows:    9676
# (_dystack pid=9991) Train Data Columns: 16
# (_dystack pid=9991) Label Column:       count
# (_dystack pid=9991) Problem Type:       regression
# (_dystack pid=9991) Preprocessing data ...
# (_dystack pid=9991) Using Feature Generators to preprocess the data ...
# (_dystack pid=9991) Dropping user-specified ignored columns: ['casual', 'registered']
# (_dystack pid=9991) Fitting AutoMLPipelineFeatureGenerator...
# (_dystack pid=9991) 	Available Memory:                    10675.22 MB
# (_dystack pid=9991) 	Train Data (Original)  Memory Usage: 0.78 MB (0.0% of available memory)
# (_dystack pid=9991) 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# (_dystack pid=9991) 	Stage 1 Generators:
# (_dystack pid=9991) 		Fitting AsTypeFeatureGenerator...
# (_dystack pid=9991) 			Note: Converting 7 features to boolean dtype as they only contain 2 unique values.
# (_dystack pid=9991) 	Stage 2 Generators:
# (_dystack pid=9991) 		Fitting FillNaFeatureGenerator...
# (_dystack pid=9991) 	Stage 3 Generators:
# (_dystack pid=9991) 		Fitting IdentityFeatureGenerator...
# (_dystack pid=9991) 	Stage 4 Generators:
# (_dystack pid=9991) 		Fitting DropUniqueFeatureGenerator...
# (_dystack pid=9991) 	Stage 5 Generators:
# (_dystack pid=9991) 		Fitting DropDuplicatesFeatureGenerator...
# (_dystack pid=9991) 	Types of features in original data (raw dtype, special dtypes):
# (_dystack pid=9991) 		('bool', [])  : 4 | ['weather_1', 'weather_2', 'weather_3', 'weather_4']
# (_dystack pid=9991) 		('float', []) : 3 | ['temp', 'atemp', 'windspeed']
# (_dystack pid=9991) 		('int', [])   : 7 | ['holiday', 'workingday', 'humidity', 'hour', 'day', ...]
# (_dystack pid=9991) 	Types of features in processed data (raw dtype, special dtypes):
# (_dystack pid=9991) 		('float', [])     : 3 | ['temp', 'atemp', 'windspeed']
# (_dystack pid=9991) 		('int', [])       : 4 | ['humidity', 'hour', 'day', 'month']
# (_dystack pid=9991) 		('int', ['bool']) : 7 | ['holiday', 'workingday', 'weather_1', 'weather_2', 'weather_3', ...]
# (_dystack pid=9991) 	0.1s = Fit runtime
# (_dystack pid=9991) 	14 features in original data used to generate 14 features in processed data.
# (_dystack pid=9991) 	Train Data (Processed) Memory Usage: 0.58 MB (0.0% of available memory)
# (_dystack pid=9991) Data preprocessing and feature engineering runtime = 0.08s ...
# (_dystack pid=9991) AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# (_dystack pid=9991) 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# (_dystack pid=9991) 	To change this, specify the eval_metric parameter of Predictor()
# (_dystack pid=9991) Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# (_dystack pid=9991) User-specified model hyperparameters to be fit:
# (_dystack pid=9991) {
# (_dystack pid=9991) 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# (_dystack pid=9991) 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# (_dystack pid=9991) 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# (_dystack pid=9991) 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# (_dystack pid=9991) 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# (_dystack pid=9991) 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=9991) 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# (_dystack pid=9991) }
# (_dystack pid=9991) AutoGluon will fit 2 stack levels (L1 to L2) ...
# (_dystack pid=9991) Fitting 106 L1 models, fit_strategy="sequential" ...
# (_dystack pid=9991) Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 44.73s of the 67.10s of remaining time.
# (_dystack pid=9991) 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.09%)
# (_ray_fit pid=10174) [1000]	valid_set's rmse: 40.5637
# (_ray_fit pid=10175) 	Ran out of time, early stopping on iteration 3392. Best iteration is:
# (_ray_fit pid=10175) 	[3392]	valid_set's rmse: 35.7404
# (_ray_fit pid=10349) [1000]	valid_set's rmse: 41.9403 [repeated 6x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (_ray_fit pid=10349) [5000]	valid_set's rmse: 39.6158 [repeated 8x across cluster]
# (_ray_fit pid=10349) 	Ran out of time, early stopping on iteration 5158. Best iteration is: [repeated 2x across cluster]
# (_ray_fit pid=10349) 	[5158]	valid_set's rmse: 39.5949 [repeated 2x across cluster]
# (_ray_fit pid=10517) [1000]	valid_set's rmse: 37.2114 [repeated 2x across cluster]
# (_ray_fit pid=10517) [3000]	valid_set's rmse: 35.6854 [repeated 4x across cluster]
# (_ray_fit pid=10517) 	Ran out of time, early stopping on iteration 3164. Best iteration is: [repeated 2x across cluster]
# (_ray_fit pid=10517) 	[3116]	valid_set's rmse: 35.6236 [repeated 2x across cluster]
# (_ray_fit pid=10669) [1000]	valid_set's rmse: 38.607
# (_ray_fit pid=10670) [1000]	valid_set's rmse: 39.4405
# (_ray_fit pid=10669) [5000]	valid_set's rmse: 36.3529 [repeated 7x across cluster]
# (_ray_fit pid=10670) 	Ran out of time, early stopping on iteration 4981. Best iteration is: [repeated 2x across cluster]
# (_ray_fit pid=10670) 	[4226]	valid_set's rmse: 37.1838 [repeated 2x across cluster]
# (_dystack pid=9991) 	-37.6597	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=9991) 	88.98s	 = Training   runtime
# (_dystack pid=9991) 	12.83s	 = Validation runtime
# (_ray_fit pid=10669) 	Ran out of time, early stopping on iteration 5162. Best iteration is:
# (_ray_fit pid=10669) 	[4827]	valid_set's rmse: 36.322
# (_dystack pid=9991) Fitting model: WeightedEnsemble_L2 ... Training model for up to 67.11s of the -36.50s of remaining time.
# (_dystack pid=9991) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# (_dystack pid=9991) 	-37.6597	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=9991) 	0.0s	 = Training   runtime
# (_dystack pid=9991) 	0.0s	 = Validation runtime
# (_dystack pid=9991) Fitting 106 L2 models, fit_strategy="sequential" ...
# (_dystack pid=9991) Fitting model: WeightedEnsemble_L3 ... Training model for up to 67.11s of the -36.68s of remaining time.
# (_dystack pid=9991) 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# (_dystack pid=9991) 	-37.6597	 = Validation score   (-root_mean_squared_error)
# (_dystack pid=9991) 	0.01s	 = Training   runtime
# (_dystack pid=9991) 	0.0s	 = Validation runtime
# (_dystack pid=9991) AutoGluon training complete, total runtime = 103.91s ... Best model: WeightedEnsemble_L2 | Estimated inference throughput: 94.3 rows/s (1210 batch size)
# (_dystack pid=9991) TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/AutogluonModels/ag-20250919_223521/ds_sub_fit/sub_fit_ho")
# (_dystack pid=9991) Deleting DyStack predictor artifacts (clean_up_fits=True) ...
# Leaderboard on holdout data (DyStack):
#                  model  score_holdout  score_val              eval_metric  pred_time_test  pred_time_val   fit_time  pred_time_test_marginal  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0    LightGBMXT_BAG_L1     -36.191621 -37.659658  root_mean_squared_error       11.824881      12.830593  88.982686                11.824881               12.830593          88.982686            1       True          1
# 1  WeightedEnsemble_L3     -36.191621 -37.659658  root_mean_squared_error       11.827541      12.834101  88.991847                 0.002660                0.003508           0.009161            3       True          3
# 2  WeightedEnsemble_L2     -36.191621 -37.659658  root_mean_squared_error       11.828678      12.831476  88.987000                 0.003797                0.000883           0.004314            2       True          2
# 	1	 = Optimal   num_stack_levels (Stacked Overfitting Occurred: False)
# 	131s	 = DyStack   runtime |	169s	 = Remaining runtime
# Starting main fit with num_stack_levels=1.
# 	For future fit calls on this dataset, you can skip DyStack to save time: `predictor.fit(..., dynamic_stacking=False, num_stack_levels=1)`
# Beginning AutoGluon training ... Time limit = 169s
# AutoGluon will save models to "/content/AutogluonModels/ag-20250919_223521"
# Train Data Rows:    10886
# Train Data Columns: 16
# Label Column:       count
# Problem Type:       regression
# Preprocessing data ...
# Using Feature Generators to preprocess the data ...
# Dropping user-specified ignored columns: ['casual', 'registered']
# Fitting AutoMLPipelineFeatureGenerator...
# 	Available Memory:                    10313.02 MB
# 	Train Data (Original)  Memory Usage: 0.87 MB (0.0% of available memory)
# 	Inferring data type of each feature based on column values. Set feature_metadata_in to manually specify special dtypes of the features.
# 	Stage 1 Generators:
# 		Fitting AsTypeFeatureGenerator...
# 			Note: Converting 7 features to boolean dtype as they only contain 2 unique values.
# 	Stage 2 Generators:
# 		Fitting FillNaFeatureGenerator...
# 	Stage 3 Generators:
# 		Fitting IdentityFeatureGenerator...
# 	Stage 4 Generators:
# 		Fitting DropUniqueFeatureGenerator...
# 	Stage 5 Generators:
# 		Fitting DropDuplicatesFeatureGenerator...
# 	Types of features in original data (raw dtype, special dtypes):
# 		('bool', [])  : 4 | ['weather_1', 'weather_2', 'weather_3', 'weather_4']
# 		('float', []) : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])   : 7 | ['holiday', 'workingday', 'humidity', 'hour', 'day', ...]
# 	Types of features in processed data (raw dtype, special dtypes):
# 		('float', [])     : 3 | ['temp', 'atemp', 'windspeed']
# 		('int', [])       : 4 | ['humidity', 'hour', 'day', 'month']
# 		('int', ['bool']) : 7 | ['holiday', 'workingday', 'weather_1', 'weather_2', 'weather_3', ...]
# 	0.1s = Fit runtime
# 	14 features in original data used to generate 14 features in processed data.
# 	Train Data (Processed) Memory Usage: 0.65 MB (0.0% of available memory)
# Data preprocessing and feature engineering runtime = 0.14s ...
# AutoGluon will gauge predictive performance using evaluation metric: 'root_mean_squared_error'
# 	This metric's sign has been flipped to adhere to being higher_is_better. The metric score can be multiplied by -1 to get the metric value.
# 	To change this, specify the eval_metric parameter of Predictor()
# Large model count detected (110 configs) ... Only displaying the first 3 models of each family. To see all, set `verbosity=3`.
# User-specified model hyperparameters to be fit:
# {
# 	'NN_TORCH': [{}, {'activation': 'elu', 'dropout_prob': 0.10077639529843717, 'hidden_size': 108, 'learning_rate': 0.002735937344002146, 'num_layers': 4, 'use_batchnorm': True, 'weight_decay': 1.356433327634438e-12, 'ag_args': {'name_suffix': '_r79', 'priority': -2}}, {'activation': 'elu', 'dropout_prob': 0.11897478034205347, 'hidden_size': 213, 'learning_rate': 0.0010474382260641949, 'num_layers': 4, 'use_batchnorm': False, 'weight_decay': 5.594471067786272e-10, 'ag_args': {'name_suffix': '_r22', 'priority': -7}}],
# 	'GBM': [{'extra_trees': True, 'ag_args': {'name_suffix': 'XT'}}, {}, {'learning_rate': 0.03, 'num_leaves': 128, 'feature_fraction': 0.9, 'min_data_in_leaf': 3, 'ag_args': {'name_suffix': 'Large', 'priority': 0, 'hyperparameter_tune_kwargs': None}}],
# 	'CAT': [{}, {'depth': 6, 'grow_policy': 'SymmetricTree', 'l2_leaf_reg': 2.1542798306067823, 'learning_rate': 0.06864209415792857, 'max_ctr_complexity': 4, 'one_hot_max_size': 10, 'ag_args': {'name_suffix': '_r177', 'priority': -1}}, {'depth': 8, 'grow_policy': 'Depthwise', 'l2_leaf_reg': 2.7997999596449104, 'learning_rate': 0.031375015734637225, 'max_ctr_complexity': 2, 'one_hot_max_size': 3, 'ag_args': {'name_suffix': '_r9', 'priority': -5}}],
# 	'XGB': [{}, {'colsample_bytree': 0.6917311125174739, 'enable_categorical': False, 'learning_rate': 0.018063876087523967, 'max_depth': 10, 'min_child_weight': 0.6028633586934382, 'ag_args': {'name_suffix': '_r33', 'priority': -8}}, {'colsample_bytree': 0.6628423832084077, 'enable_categorical': False, 'learning_rate': 0.08775715546881824, 'max_depth': 5, 'min_child_weight': 0.6294123374222513, 'ag_args': {'name_suffix': '_r89', 'priority': -16}}],
# 	'FASTAI': [{}, {'bs': 256, 'emb_drop': 0.5411770367537934, 'epochs': 43, 'layers': [800, 400], 'lr': 0.01519848858318159, 'ps': 0.23782946566604385, 'ag_args': {'name_suffix': '_r191', 'priority': -4}}, {'bs': 2048, 'emb_drop': 0.05070411322605811, 'epochs': 29, 'layers': [200, 100], 'lr': 0.08974235041576624, 'ps': 0.10393466140748028, 'ag_args': {'name_suffix': '_r102', 'priority': -11}}],
# 	'RF': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# 	'XT': [{'criterion': 'gini', 'ag_args': {'name_suffix': 'Gini', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'entropy', 'ag_args': {'name_suffix': 'Entr', 'problem_types': ['binary', 'multiclass']}}, {'criterion': 'squared_error', 'ag_args': {'name_suffix': 'MSE', 'problem_types': ['regression', 'quantile']}}],
# }
# AutoGluon will fit 2 stack levels (L1 to L2) ...
# Fitting 106 L1 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L1 ... Training model for up to 112.57s of the 168.87s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.09%)
# 	-36.6075	 = Validation score   (-root_mean_squared_error)
# 	116.75s	 = Training   runtime
# 	31.13s	 = Validation runtime
# Fitting model: WeightedEnsemble_L2 ... Training model for up to 168.89s of the 42.47s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 1.0}
# 	-36.6075	 = Validation score   (-root_mean_squared_error)
# 	0.0s	 = Training   runtime
# 	0.0s	 = Validation runtime
# Fitting 106 L2 models, fit_strategy="sequential" ...
# Fitting model: LightGBMXT_BAG_L2 ... Training model for up to 42.46s of the 42.44s of remaining time.
# 	Fitting 8 child models (S1F1 - S1F8) | Fitting with ParallelLocalFoldFittingStrategy (2 workers, per: cpus=1, gpus=0, memory=0.10%)
# 	-38.0959	 = Validation score   (-root_mean_squared_error)
# 	39.22s	 = Training   runtime
# 	0.55s	 = Validation runtime
# Fitting model: WeightedEnsemble_L3 ... Training model for up to 168.89s of the -3.71s of remaining time.
# 	Ensemble Weights: {'LightGBMXT_BAG_L1': 0.955, 'LightGBMXT_BAG_L2': 0.045}
# 	-36.6039	 = Validation score   (-root_mean_squared_error)
# 	0.02s	 = Training   runtime
# 	0.0s	 = Validation runtime
# AutoGluon training complete, total runtime = 172.8s ... Best model: WeightedEnsemble_L3 | Estimated inference throughput: 43.0 rows/s (1361 batch size)
# TabularPredictor saved. To load, use: predictor = TabularPredictor.load("/content/AutogluonModels/ag-20250919_223521")

# %%
predictor.fit_summary()
# Out:
# *** Summary of fit() ***
# Estimated performance of each model:
#                  model  score_val              eval_metric  pred_time_val    fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  can_infer  fit_order
# 0  WeightedEnsemble_L3 -36.603915  root_mean_squared_error      31.678718  155.984835                0.000944           0.016053            3       True          4
# 1    LightGBMXT_BAG_L1 -36.607462  root_mean_squared_error      31.130778  116.752339               31.130778         116.752339            1       True          1
# 2  WeightedEnsemble_L2 -36.607462  root_mean_squared_error      31.131455  116.756262                0.000677           0.003923            2       True          2
# 3    LightGBMXT_BAG_L2 -38.095905  root_mean_squared_error      31.677773  155.968782                0.546995          39.216443            2       True          3
# Number of models trained: 4
# Types of models trained:
# {'StackerEnsembleModel_LGB', 'WeightedEnsembleModel'}
# Bagging used: True  (with 8 folds)
# Multi-layer stack-ensembling used: True  (with 3 levels)
# Feature Metadata (Processed):
# (raw dtype, special dtypes):
# ('float', [])     : 3 | ['temp', 'atemp', 'windspeed']
# ('int', [])       : 4 | ['humidity', 'hour', 'day', 'month']
# ('int', ['bool']) : 7 | ['holiday', 'workingday', 'weather_1', 'weather_2', 'weather_3', ...]
# Plot summary of models saved to file: /content/AutogluonModels/ag-20250919_223521/SummaryOfModels.html
# *** End of fit() summary ***
# {'model_types': {'LightGBMXT_BAG_L1': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L2': 'WeightedEnsembleModel',
#   'LightGBMXT_BAG_L2': 'StackerEnsembleModel_LGB',
#   'WeightedEnsemble_L3': 'WeightedEnsembleModel'},
#  'model_performance': {'LightGBMXT_BAG_L1': np.float64(-36.60746229333992),
#   'WeightedEnsemble_L2': np.float64(-36.60746229333992),
#   'LightGBMXT_BAG_L2': np.float64(-38.09590466067599),
#   'WeightedEnsemble_L3': np.float64(-36.603914558688)},
#  'model_best': 'WeightedEnsemble_L3',
#  'model_paths': {'LightGBMXT_BAG_L1': ['LightGBMXT_BAG_L1'],
#   'WeightedEnsemble_L2': ['WeightedEnsemble_L2'],
#   'LightGBMXT_BAG_L2': ['LightGBMXT_BAG_L2'],
#   'WeightedEnsemble_L3': ['WeightedEnsemble_L3']},
#  'model_fit_times': {'LightGBMXT_BAG_L1': 116.75233912467957,
#   'WeightedEnsemble_L2': 0.003923177719116211,
#   'LightGBMXT_BAG_L2': 39.21644306182861,
#   'WeightedEnsemble_L3': 0.016053199768066406},
#  'model_pred_times': {'LightGBMXT_BAG_L1': 31.130778074264526,
#   'WeightedEnsemble_L2': 0.0006771087646484375,
#   'LightGBMXT_BAG_L2': 0.5469954013824463,
#   'WeightedEnsemble_L3': 0.0009441375732421875},
#  'num_bag_folds': 8,
#  'max_stack_level': 3,
#  'model_hyperparams': {'LightGBMXT_BAG_L1': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'WeightedEnsemble_L2': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'LightGBMXT_BAG_L2': {'use_orig_features': True,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None},
#   'WeightedEnsemble_L3': {'use_orig_features': False,
#    'valid_stacker': True,
#    'max_base_models': 0,
#    'max_base_models_per_type': 'auto',
#    'save_bag_folds': True,
#    'stratify': 'auto',
#    'bin': 'auto',
#    'n_bins': None}},
#  'leaderboard':                  model  score_val              eval_metric  pred_time_val  \
#  0  WeightedEnsemble_L3 -36.603915  root_mean_squared_error      31.678718
#  1    LightGBMXT_BAG_L1 -36.607462  root_mean_squared_error      31.130778
#  2  WeightedEnsemble_L2 -36.607462  root_mean_squared_error      31.131455
#  3    LightGBMXT_BAG_L2 -38.095905  root_mean_squared_error      31.677773
#
#       fit_time  pred_time_val_marginal  fit_time_marginal  stack_level  \
#  0  155.984835                0.000944           0.016053            3
#  1  116.752339               31.130778         116.752339            1
#  2  116.756262                0.000677           0.003923            2
#  3  155.968782                0.546995          39.216443            2
#
#     can_infer  fit_order
#  0       True          4
#  1       True          1
#  2       True          2
#  3       True          3  }

# %%
predictor.leaderboard(silent = True).plot(kind = 'bar',x = 'model',y = 'score_val')
# Out:
# <Axes: xlabel='model'>

# %%
predictor.get_model_names()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipython-input-997680543.py in <cell line: 0>()
# ----> 1 predictor.get_model_names()
#
# AttributeError: 'TabularPredictor' object has no attribute 'get_model_names'

# %%
predictions = predictor.predict(test)
predictions.head()
# Out:
# 0    12.902032
# 1     6.166596
# 2     5.236288
# 3     3.968246
# 4     4.155498
# Name: count, dtype: float32

# %%
predictions.describe()
# Out:
# count    6493.000000
# mean      190.406784
# std       175.082748
# min       -31.790392
# 25%        45.609573
# 50%       148.953278
# 75%       283.525879
# max       928.678772
# Name: count, dtype: float64

# %%
predictions[predictions < 0].count()
# Out:
# np.int64(154)

# %%
for a,b in enumerate(predictions):
    if b < 0:
        predictions[a] = 0

# %%
predictions.describe()
# Out:
# count    6493.000000
# mean      190.538864
# std       174.934769
# min         0.000000
# 25%        45.609573
# 50%       148.953278
# 75%       283.525879
# max       928.678772
# Name: count, dtype: float64

# %%
submission["count"] = predictions
submission.to_csv("submission.csv", index=False)

# %%
# !kaggle competitions submit -c bike-sharing-demand -f submission.csv -m "first raw submission"
# Out:
# 100% 187k/187k [00:01<00:00, 184kB/s]
# Successfully submitted to Bike Sharing Demand

# %%
# !kaggle competitions submissions -c bike-sharing-demand
#| tail -n +1 | head -n 6
# Out:
# fileName        date                        description           status                     publicScore  privateScore
# --------------  --------------------------  --------------------  -------------------------  -----------  ------------
# submission.csv  2025-09-19 22:49:13.233000  first raw submission  SubmissionStatus.COMPLETE  0.61875      0.61875

# %%
fig = pd.DataFrame(
    {
        "model": ["initial", "add_features", "hpo"],
        "score": [-84.146423, -84.146423,0.004646]
    }
).plot(x="model", y="score", figsize=(8, 6)).get_figure()
fig.savefig('model_train_score.png')
